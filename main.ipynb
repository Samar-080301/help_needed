# %%
import pandas as pd

# %%
orders = pd.read_excel('Orders.xlsm')
orders.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0  B-25601    1275   -1148         7    Furniture         Bookcases
# 1  B-25601      66     -12         5     Clothing             Stole
# 2  B-25601       8      -2         3     Clothing       Hankerchief
# 3  B-25601      80     -56         4  Electronics  Electronic Games
# 4  B-25602     168    -111         2  Electronics            Phones

# %%
Categorica_orders = orders.groupby(['Order ID','Category']).sum()

# %%
Categorica_orders
# Out:
#                       Amount  Profit  Quantity
# Order ID Category
# B-25601  Clothing         74     -14         8
#          Electronics      80     -56         4
#          Furniture      1275   -1148         7
# B-25602  Clothing        680     207        11
#          Electronics    3209     768        11
# ...                      ...     ...       ...
# B-26098  Furniture       497     179         3
# B-26099  Clothing       2582     592        10
#          Electronics     835     267         5
# B-26100  Clothing        106      26         4
#          Furniture       828     230         2
#
# [783 rows x 3 columns]

# %%
customers = pd.read_excel('Customers.xlsm')
customers.head()
# Out:
#   Order ID           Order Date CustomerName           State       City
# 0  B-25601  2018-01-04 00:00:00       Bharat         Gujarat  Ahmedabad
# 1  B-25602  2018-01-04 00:00:00        Pearl     Maharashtra       Pune
# 2  B-25603  2018-03-04 00:00:00        Jahan  Madhya Pradesh     Bhopal
# 3  B-25604  2018-03-04 00:00:00       Divsha       Rajasthan     Jaipur
# 4  B-25605  2018-05-04 00:00:00      Kasheen     West Bengal    Kolkata

# %%
customers.dtypes
# Out:
# Order ID        object
# Order Date      object
# CustomerName    object
# State           object
# City            object
# dtype: object

# %%
df['date_column'] = pd.to_datetime(df['Order_Date']).dt.date
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/samar/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///home/samar/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///home/samar/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# ...
